# %%
import gymnasium as gym
import numpy as np
from stable_baselines3 import PPO
from stable_baselines3.common.env_util import make_vec_env
from stable_baselines3.common.evaluation import evaluate_policy
from stable_baselines3.common.callbacks import EvalCallback

# %%
env = make_vec_env('CarRacing-v3', n_envs=4)
model = PPO('MlpPolicy', env, verbose=1, 
            learning_rate=0.0003,
            n_steps=2048,
            batch_size=64,
            device='cuda'
            )
# Out:
# Using cpu device
# Wrapping the env in a VecTransposeImage.

# %%
mean_reward, std_reward = evaluate_policy(model, env, n_eval_episodes=100)
print(f"mean_reward:{mean_reward:.2f} +/- {std_reward:.2f}")
# Out:
# mean_reward:-15.85 +/- 19.12

# %%
model.learn(total_timesteps=100000)
# Out:
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | -54.6    |
# | time/              |          |
# |    fps             | 95       |
# |    iterations      | 1        |
# |    time_elapsed    | 85       |
# |    total_timesteps | 8192     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -51.9       |
# | time/                   |             |
# |    fps                  | 80          |
# |    iterations           | 2           |
# |    time_elapsed         | 204         |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.006259799 |
# |    clip_fraction        | 0.072       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.24       |
# |    explained_variance   | 0.0161      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.557       |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.00432    |
# |    std                  | 0.994       |
# |    value_loss           | 0.92        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | -48.7        |
# | time/                   |              |
# |    fps                  | 76           |
# |    iterations           | 3            |
# |    time_elapsed         | 322          |
# |    total_timesteps      | 24576        |
# | train/                  |              |
# |    approx_kl            | 0.0059330342 |
# |    clip_fraction        | 0.0593       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.23        |
# |    explained_variance   | 0.022        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.429        |
# |    n_updates            | 20           |
# |    policy_gradient_loss | -0.00411     |
# |    std                  | 0.985        |
# |    value_loss           | 0.837        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -48.1       |
# | time/                   |             |
# |    fps                  | 74          |
# |    iterations           | 4           |
# |    time_elapsed         | 439         |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.006533322 |
# |    clip_fraction        | 0.0686      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.17       |
# |    explained_variance   | 0.0268      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.381       |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.00429    |
# |    std                  | 0.968       |
# |    value_loss           | 0.972       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -44.9       |
# | time/                   |             |
# |    fps                  | 73          |
# |    iterations           | 5           |
# |    time_elapsed         | 556         |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.008475268 |
# |    clip_fraction        | 0.0777      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.12       |
# |    explained_variance   | 0.0339      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.371       |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.00484    |
# |    std                  | 0.951       |
# |    value_loss           | 0.922       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | -44          |
# | time/                   |              |
# |    fps                  | 72           |
# |    iterations           | 6            |
# |    time_elapsed         | 673          |
# |    total_timesteps      | 49152        |
# | train/                  |              |
# |    approx_kl            | 0.0066444883 |
# |    clip_fraction        | 0.0753       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.07        |
# |    explained_variance   | 0.0248       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.492        |
# |    n_updates            | 50           |
# |    policy_gradient_loss | -0.00576     |
# |    std                  | 0.936        |
# |    value_loss           | 1.09         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | -42.9        |
# | time/                   |              |
# |    fps                  | 72           |
# |    iterations           | 7            |
# |    time_elapsed         | 791          |
# |    total_timesteps      | 57344        |
# | train/                  |              |
# |    approx_kl            | 0.0069892816 |
# |    clip_fraction        | 0.0522       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.02        |
# |    explained_variance   | 0.0283       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.626        |
# |    n_updates            | 60           |
# |    policy_gradient_loss | -0.00352     |
# |    std                  | 0.919        |
# |    value_loss           | 1.33         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | -42.4        |
# | time/                   |              |
# |    fps                  | 72           |
# |    iterations           | 8            |
# |    time_elapsed         | 907          |
# |    total_timesteps      | 65536        |
# | train/                  |              |
# |    approx_kl            | 0.0061393287 |
# |    clip_fraction        | 0.0549       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.97        |
# |    explained_variance   | 0.0267       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.859        |
# |    n_updates            | 70           |
# |    policy_gradient_loss | -0.00368     |
# |    std                  | 0.906        |
# |    value_loss           | 1.45         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1e+03        |
# |    ep_rew_mean          | -43.2        |
# | time/                   |              |
# |    fps                  | 71           |
# |    iterations           | 9            |
# |    time_elapsed         | 1024         |
# |    total_timesteps      | 73728        |
# | train/                  |              |
# |    approx_kl            | 0.0063122623 |
# |    clip_fraction        | 0.0502       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.94        |
# |    explained_variance   | 0.0256       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.97         |
# |    n_updates            | 80           |
# |    policy_gradient_loss | -0.00273     |
# |    std                  | 0.901        |
# |    value_loss           | 1.89         |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | -42.2      |
# | time/                   |            |
# |    fps                  | 71         |
# |    iterations           | 10         |
# |    time_elapsed         | 1141       |
# |    total_timesteps      | 81920      |
# | train/                  |            |
# |    approx_kl            | 0.00650686 |
# |    clip_fraction        | 0.0564     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.89      |
# |    explained_variance   | 0.026      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.38       |
# |    n_updates            | 90         |
# |    policy_gradient_loss | -0.00297   |
# |    std                  | 0.88       |
# |    value_loss           | 2          |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 998          |
# |    ep_rew_mean          | -46.9        |
# | time/                   |              |
# |    fps                  | 71           |
# |    iterations           | 11           |
# |    time_elapsed         | 1256         |
# |    total_timesteps      | 90112        |
# | train/                  |              |
# |    approx_kl            | 0.0051669776 |
# |    clip_fraction        | 0.0279       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.83        |
# |    explained_variance   | 0.0202       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.925        |
# |    n_updates            | 100          |
# |    policy_gradient_loss | -0.00126     |
# |    std                  | 0.866        |
# |    value_loss           | 2.6          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 997          |
# |    ep_rew_mean          | -48          |
# | time/                   |              |
# |    fps                  | 71           |
# |    iterations           | 12           |
# |    time_elapsed         | 1371         |
# |    total_timesteps      | 98304        |
# | train/                  |              |
# |    approx_kl            | 0.0039084526 |
# |    clip_fraction        | 0.0478       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.82        |
# |    explained_variance   | -0.0887      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.16         |
# |    n_updates            | 110          |
# |    policy_gradient_loss | -0.000929    |
# |    std                  | 0.866        |
# |    value_loss           | 23.2         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 994          |
# |    ep_rew_mean          | -50.5        |
# | time/                   |              |
# |    fps                  | 71           |
# |    iterations           | 13           |
# |    time_elapsed         | 1487         |
# |    total_timesteps      | 106496       |
# | train/                  |              |
# |    approx_kl            | 0.0053989994 |
# |    clip_fraction        | 0.0384       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.79        |
# |    explained_variance   | 0.000935     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.45         |
# |    n_updates            | 120          |
# |    policy_gradient_loss | -0.00018     |
# |    std                  | 0.854        |
# |    value_loss           | 11.6         |
# ------------------------------------------

# %%
mean_reward, std_reward = evaluate_policy(model, env, n_eval_episodes=100)
print(f"mean_reward:{mean_reward:.2f} +/- {std_reward:.2f}")
# Out:
# mean_reward:-76.26 +/- 1.72

# %%
model.save("carRace_ppo")

# %%
import gymnasium as gym
from stable_baselines3 import PPO

# Eğitilmiş modeli yükle
model = PPO.load("carRace_ppo.zip")

# Ortamı oluştur (görselleştirme açık)
env = gym.make("CarRacing-v3", render_mode="human")

episode_sayisi = 5  # 5 bölüm boyunca izle
for episode in range(episode_sayisi):
    obs, _ = env.reset()
    done = False
    total_reward = 0

    while not done:
        action, _ = model.predict(obs, deterministic=True)
        obs, reward, terminated, truncated, info = env.step(action)
        total_reward += reward
        done = terminated or truncated

    print(f"Bölüm {episode + 1}: Toplam Ödül = {total_reward}")

# Ortamı kapat
env.close()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import gymnasium as gym
#       2 from stable_baselines3 import PPO
#       4 # Eğitilmiş modeli yükle
#
# ModuleNotFoundError: No module named 'gymnasium'
