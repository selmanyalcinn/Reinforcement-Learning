# %%
import gymnasium as gym
import numpy as np
from stable_baselines3 import PPO
from stable_baselines3.common.env_util import make_vec_env
from stable_baselines3.common.evaluation import evaluate_policy
from stable_baselines3.common.callbacks import EvalCallback

# %%
env = make_vec_env('LunarLander-v3', n_envs=4)
model = PPO('MlpPolicy', env, verbose=1, 
            learning_rate=0.0003,
            n_steps=2048,
            batch_size=64,
            device='cuda'
            )
# Out:
# Using cpu device

# %%
mean_reward, std_reward = evaluate_policy(model, env, n_eval_episodes=100)
print(f"mean_reward:{mean_reward:.2f} +/- {std_reward:.2f}")
# Out:
# mean_reward:-337.52 +/- 254.74

# %%
model.learn(total_timesteps=1000000)
# Out:
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 92.6     |
# |    ep_rew_mean     | -176     |
# | time/              |          |
# |    fps             | 3370     |
# |    iterations      | 1        |
# |    time_elapsed    | 2        |
# |    total_timesteps | 8192     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 95.8        |
# |    ep_rew_mean          | -166        |
# | time/                   |             |
# |    fps                  | 2048        |
# |    iterations           | 2           |
# |    time_elapsed         | 7           |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.007915219 |
# |    clip_fraction        | 0.0546      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.38       |
# |    explained_variance   | -0.000687   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 351         |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.00659    |
# |    value_loss           | 1.01e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 96          |
# |    ep_rew_mean          | -139        |
# | time/                   |             |
# |    fps                  | 1827        |
# |    iterations           | 3           |
# |    time_elapsed         | 13          |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.008676389 |
# |    clip_fraction        | 0.0656      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.36       |
# |    explained_variance   | 0.153       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 262         |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.00718    |
# |    value_loss           | 629         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 102         |
# |    ep_rew_mean          | -120        |
# | time/                   |             |
# |    fps                  | 1717        |
# |    iterations           | 4           |
# |    time_elapsed         | 19          |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.012160695 |
# |    clip_fraction        | 0.134       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.33       |
# |    explained_variance   | 0.192       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 155         |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0111     |
# |    value_loss           | 324         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 121         |
# |    ep_rew_mean          | -94.3       |
# | time/                   |             |
# |    fps                  | 1566        |
# |    iterations           | 5           |
# |    time_elapsed         | 26          |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.009845432 |
# |    clip_fraction        | 0.0976      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.3        |
# |    explained_variance   | 0.209       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 122         |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0114     |
# |    value_loss           | 315         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 124         |
# |    ep_rew_mean          | -78.2       |
# | time/                   |             |
# |    fps                  | 1507        |
# |    iterations           | 6           |
# |    time_elapsed         | 32          |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.011077345 |
# |    clip_fraction        | 0.12        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.24       |
# |    explained_variance   | 0.0224      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 222         |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.0108     |
# |    value_loss           | 252         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 148          |
# |    ep_rew_mean          | -67.6        |
# | time/                   |              |
# |    fps                  | 1470         |
# |    iterations           | 7            |
# |    time_elapsed         | 38           |
# |    total_timesteps      | 57344        |
# | train/                  |              |
# |    approx_kl            | 0.0124976635 |
# |    clip_fraction        | 0.136        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.18        |
# |    explained_variance   | 0.166        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 141          |
# |    n_updates            | 60           |
# |    policy_gradient_loss | -0.0123      |
# |    value_loss           | 290          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 183         |
# |    ep_rew_mean          | -57.9       |
# | time/                   |             |
# |    fps                  | 1396        |
# |    iterations           | 8           |
# |    time_elapsed         | 46          |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.011494563 |
# |    clip_fraction        | 0.111       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.12       |
# |    explained_variance   | 0.469       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 135         |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.0113     |
# |    value_loss           | 219         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 220         |
# |    ep_rew_mean          | -62         |
# | time/                   |             |
# |    fps                  | 1305        |
# |    iterations           | 9           |
# |    time_elapsed         | 56          |
# |    total_timesteps      | 73728       |
# | train/                  |             |
# |    approx_kl            | 0.010728111 |
# |    clip_fraction        | 0.0987      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.1        |
# |    explained_variance   | 0.637       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 63.2        |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.00848    |
# |    value_loss           | 166         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 270         |
# |    ep_rew_mean          | -58.2       |
# | time/                   |             |
# |    fps                  | 1245        |
# |    iterations           | 10          |
# |    time_elapsed         | 65          |
# |    total_timesteps      | 81920       |
# | train/                  |             |
# |    approx_kl            | 0.009043241 |
# |    clip_fraction        | 0.0958      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.12       |
# |    explained_variance   | 0.729       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 56.4        |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.0087     |
# |    value_loss           | 116         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 315         |
# |    ep_rew_mean          | -54.3       |
# | time/                   |             |
# |    fps                  | 1185        |
# |    iterations           | 11          |
# |    time_elapsed         | 75          |
# |    total_timesteps      | 90112       |
# | train/                  |             |
# |    approx_kl            | 0.008056042 |
# |    clip_fraction        | 0.0818      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.11       |
# |    explained_variance   | 0.747       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 88.5        |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.00657    |
# |    value_loss           | 113         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 377          |
# |    ep_rew_mean          | -52.6        |
# | time/                   |              |
# |    fps                  | 1128         |
# |    iterations           | 12           |
# |    time_elapsed         | 87           |
# |    total_timesteps      | 98304        |
# | train/                  |              |
# |    approx_kl            | 0.0085309055 |
# |    clip_fraction        | 0.0955       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.1         |
# |    explained_variance   | 0.744        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 18.3         |
# |    n_updates            | 110          |
# |    policy_gradient_loss | -0.00668     |
# |    value_loss           | 85.5         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 421         |
# |    ep_rew_mean          | -48.5       |
# | time/                   |             |
# |    fps                  | 1093        |
# |    iterations           | 13          |
# |    time_elapsed         | 97          |
# |    total_timesteps      | 106496      |
# | train/                  |             |
# |    approx_kl            | 0.011562752 |
# |    clip_fraction        | 0.0792      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.07       |
# |    explained_variance   | 0.75        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 22.7        |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.0067     |
# |    value_loss           | 71.9        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 472         |
# |    ep_rew_mean          | -37.3       |
# | time/                   |             |
# |    fps                  | 1048        |
# |    iterations           | 14          |
# |    time_elapsed         | 109         |
# |    total_timesteps      | 114688      |
# | train/                  |             |
# |    approx_kl            | 0.011778734 |
# |    clip_fraction        | 0.145       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.03       |
# |    explained_variance   | 0.745       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 28.7        |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.00748    |
# |    value_loss           | 73.7        |
# -----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 533       |
# |    ep_rew_mean          | -27.6     |
# | time/                   |           |
# |    fps                  | 1014      |
# |    iterations           | 15        |
# |    time_elapsed         | 121       |
# |    total_timesteps      | 122880    |
# | train/                  |           |
# |    approx_kl            | 0.0117619 |
# |    clip_fraction        | 0.115     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -1        |
# |    explained_variance   | 0.864     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 14.4      |
# |    n_updates            | 140       |
# |    policy_gradient_loss | -0.00851  |
# |    value_loss           | 26        |
# ---------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 583         |
# |    ep_rew_mean          | -13.9       |
# | time/                   |             |
# |    fps                  | 980         |
# |    iterations           | 16          |
# |    time_elapsed         | 133         |
# |    total_timesteps      | 131072      |
# | train/                  |             |
# |    approx_kl            | 0.006437957 |
# |    clip_fraction        | 0.0798      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.986      |
# |    explained_variance   | 0.864       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 12.7        |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.00652    |
# |    value_loss           | 26.5        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 614          |
# |    ep_rew_mean          | 0.725        |
# | time/                   |              |
# |    fps                  | 957          |
# |    iterations           | 17           |
# |    time_elapsed         | 145          |
# |    total_timesteps      | 139264       |
# | train/                  |              |
# |    approx_kl            | 0.0076028453 |
# |    clip_fraction        | 0.0798       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.868       |
# |    explained_variance   | 0.865        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.2          |
# |    n_updates            | 160          |
# |    policy_gradient_loss | -0.00359     |
# |    value_loss           | 24.3         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 648         |
# |    ep_rew_mean          | 29.3        |
# | time/                   |             |
# |    fps                  | 935         |
# |    iterations           | 18          |
# |    time_elapsed         | 157         |
# |    total_timesteps      | 147456      |
# | train/                  |             |
# |    approx_kl            | 0.012539908 |
# |    clip_fraction        | 0.103       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.83       |
# |    explained_variance   | 0.724       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 12.7        |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.00482    |
# |    value_loss           | 38.4        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 651        |
# |    ep_rew_mean          | 59.3       |
# | time/                   |            |
# |    fps                  | 928        |
# |    iterations           | 19         |
# |    time_elapsed         | 167        |
# |    total_timesteps      | 155648     |
# | train/                  |            |
# |    approx_kl            | 0.03392627 |
# |    clip_fraction        | 0.11       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.814     |
# |    explained_variance   | 0.44       |
# |    learning_rate        | 0.0003     |
# |    loss                 | 40.5       |
# |    n_updates            | 180        |
# |    policy_gradient_loss | -0.01      |
# |    value_loss           | 144        |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 648         |
# |    ep_rew_mean          | 89.4        |
# | time/                   |             |
# |    fps                  | 919         |
# |    iterations           | 20          |
# |    time_elapsed         | 178         |
# |    total_timesteps      | 163840      |
# | train/                  |             |
# |    approx_kl            | 0.006532815 |
# |    clip_fraction        | 0.0604      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.843      |
# |    explained_variance   | 0.457       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 118         |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.00293    |
# |    value_loss           | 160         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 597          |
# |    ep_rew_mean          | 121          |
# | time/                   |              |
# |    fps                  | 917          |
# |    iterations           | 21           |
# |    time_elapsed         | 187          |
# |    total_timesteps      | 172032       |
# | train/                  |              |
# |    approx_kl            | 0.0045228032 |
# |    clip_fraction        | 0.0636       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.864       |
# |    explained_variance   | 0.628        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 79.8         |
# |    n_updates            | 200          |
# |    policy_gradient_loss | -0.000908    |
# |    value_loss           | 128          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 518          |
# |    ep_rew_mean          | 142          |
# | time/                   |              |
# |    fps                  | 916          |
# |    iterations           | 22           |
# |    time_elapsed         | 196          |
# |    total_timesteps      | 180224       |
# | train/                  |              |
# |    approx_kl            | 0.0050658374 |
# |    clip_fraction        | 0.0451       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.834       |
# |    explained_variance   | 0.653        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 44.8         |
# |    n_updates            | 210          |
# |    policy_gradient_loss | -0.00225     |
# |    value_loss           | 143          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 465          |
# |    ep_rew_mean          | 157          |
# | time/                   |              |
# |    fps                  | 913          |
# |    iterations           | 23           |
# |    time_elapsed         | 206          |
# |    total_timesteps      | 188416       |
# | train/                  |              |
# |    approx_kl            | 0.0061500957 |
# |    clip_fraction        | 0.0419       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.781       |
# |    explained_variance   | 0.631        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 97.3         |
# |    n_updates            | 220          |
# |    policy_gradient_loss | -0.0035      |
# |    value_loss           | 137          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 451         |
# |    ep_rew_mean          | 171         |
# | time/                   |             |
# |    fps                  | 914         |
# |    iterations           | 24          |
# |    time_elapsed         | 215         |
# |    total_timesteps      | 196608      |
# | train/                  |             |
# |    approx_kl            | 0.004738236 |
# |    clip_fraction        | 0.0443      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.833      |
# |    explained_variance   | 0.728       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 43.2        |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.00258    |
# |    value_loss           | 106         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 437         |
# |    ep_rew_mean          | 162         |
# | time/                   |             |
# |    fps                  | 912         |
# |    iterations           | 25          |
# |    time_elapsed         | 224         |
# |    total_timesteps      | 204800      |
# | train/                  |             |
# |    approx_kl            | 0.005626661 |
# |    clip_fraction        | 0.0533      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.79       |
# |    explained_variance   | 0.805       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 22.5        |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.00209    |
# |    value_loss           | 69.8        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 429         |
# |    ep_rew_mean          | 162         |
# | time/                   |             |
# |    fps                  | 913         |
# |    iterations           | 26          |
# |    time_elapsed         | 233         |
# |    total_timesteps      | 212992      |
# | train/                  |             |
# |    approx_kl            | 0.004952363 |
# |    clip_fraction        | 0.0302      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.813      |
# |    explained_variance   | 0.616       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 196         |
# |    n_updates            | 250         |
# |    policy_gradient_loss | -0.00175    |
# |    value_loss           | 162         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 424          |
# |    ep_rew_mean          | 162          |
# | time/                   |              |
# |    fps                  | 914          |
# |    iterations           | 27           |
# |    time_elapsed         | 241          |
# |    total_timesteps      | 221184       |
# | train/                  |              |
# |    approx_kl            | 0.0054533184 |
# |    clip_fraction        | 0.0359       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.838       |
# |    explained_variance   | 0.804        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 27.4         |
# |    n_updates            | 260          |
# |    policy_gradient_loss | -0.000961    |
# |    value_loss           | 106          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 413          |
# |    ep_rew_mean          | 159          |
# | time/                   |              |
# |    fps                  | 915          |
# |    iterations           | 28           |
# |    time_elapsed         | 250          |
# |    total_timesteps      | 229376       |
# | train/                  |              |
# |    approx_kl            | 0.0038601633 |
# |    clip_fraction        | 0.0297       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.812       |
# |    explained_variance   | 0.733        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 30.4         |
# |    n_updates            | 270          |
# |    policy_gradient_loss | -0.00235     |
# |    value_loss           | 120          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 415          |
# |    ep_rew_mean          | 153          |
# | time/                   |              |
# |    fps                  | 915          |
# |    iterations           | 29           |
# |    time_elapsed         | 259          |
# |    total_timesteps      | 237568       |
# | train/                  |              |
# |    approx_kl            | 0.0061692195 |
# |    clip_fraction        | 0.0369       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.798       |
# |    explained_variance   | 0.797        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 15.3         |
# |    n_updates            | 280          |
# |    policy_gradient_loss | -0.00262     |
# |    value_loss           | 113          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 417         |
# |    ep_rew_mean          | 170         |
# | time/                   |             |
# |    fps                  | 915         |
# |    iterations           | 30          |
# |    time_elapsed         | 268         |
# |    total_timesteps      | 245760      |
# | train/                  |             |
# |    approx_kl            | 0.006319628 |
# |    clip_fraction        | 0.0657      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.837      |
# |    explained_variance   | 0.788       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 73.7        |
# |    n_updates            | 290         |
# |    policy_gradient_loss | -0.00428    |
# |    value_loss           | 87.7        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 425         |
# |    ep_rew_mean          | 179         |
# | time/                   |             |
# |    fps                  | 912         |
# |    iterations           | 31          |
# |    time_elapsed         | 278         |
# |    total_timesteps      | 253952      |
# | train/                  |             |
# |    approx_kl            | 0.005438242 |
# |    clip_fraction        | 0.0545      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.778      |
# |    explained_variance   | 0.808       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 17.9        |
# |    n_updates            | 300         |
# |    policy_gradient_loss | -0.000837   |
# |    value_loss           | 73.6        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 417          |
# |    ep_rew_mean          | 184          |
# | time/                   |              |
# |    fps                  | 910          |
# |    iterations           | 32           |
# |    time_elapsed         | 288          |
# |    total_timesteps      | 262144       |
# | train/                  |              |
# |    approx_kl            | 0.0046399976 |
# |    clip_fraction        | 0.0448       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.754       |
# |    explained_variance   | 0.8          |
# |    learning_rate        | 0.0003       |
# |    loss                 | 5.02         |
# |    n_updates            | 310          |
# |    policy_gradient_loss | -0.00223     |
# |    value_loss           | 77.6         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 418         |
# |    ep_rew_mean          | 177         |
# | time/                   |             |
# |    fps                  | 911         |
# |    iterations           | 33          |
# |    time_elapsed         | 296         |
# |    total_timesteps      | 270336      |
# | train/                  |             |
# |    approx_kl            | 0.004780895 |
# |    clip_fraction        | 0.054       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.808      |
# |    explained_variance   | 0.77        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 113         |
# |    n_updates            | 320         |
# |    policy_gradient_loss | -0.00182    |
# |    value_loss           | 115         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 408         |
# |    ep_rew_mean          | 181         |
# | time/                   |             |
# |    fps                  | 914         |
# |    iterations           | 34          |
# |    time_elapsed         | 304         |
# |    total_timesteps      | 278528      |
# | train/                  |             |
# |    approx_kl            | 0.003861563 |
# |    clip_fraction        | 0.0387      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.758      |
# |    explained_variance   | 0.793       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 18.1        |
# |    n_updates            | 330         |
# |    policy_gradient_loss | -0.0025     |
# |    value_loss           | 110         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 401         |
# |    ep_rew_mean          | 179         |
# | time/                   |             |
# |    fps                  | 916         |
# |    iterations           | 35          |
# |    time_elapsed         | 312         |
# |    total_timesteps      | 286720      |
# | train/                  |             |
# |    approx_kl            | 0.006671213 |
# |    clip_fraction        | 0.0422      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.722      |
# |    explained_variance   | 0.756       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 199         |
# |    n_updates            | 340         |
# |    policy_gradient_loss | -0.00174    |
# |    value_loss           | 147         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 396         |
# |    ep_rew_mean          | 179         |
# | time/                   |             |
# |    fps                  | 917         |
# |    iterations           | 36          |
# |    time_elapsed         | 321         |
# |    total_timesteps      | 294912      |
# | train/                  |             |
# |    approx_kl            | 0.005049277 |
# |    clip_fraction        | 0.0565      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.775      |
# |    explained_variance   | 0.824       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 12.4        |
# |    n_updates            | 350         |
# |    policy_gradient_loss | -0.00301    |
# |    value_loss           | 87.1        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 406          |
# |    ep_rew_mean          | 186          |
# | time/                   |              |
# |    fps                  | 918          |
# |    iterations           | 37           |
# |    time_elapsed         | 330          |
# |    total_timesteps      | 303104       |
# | train/                  |              |
# |    approx_kl            | 0.0046990244 |
# |    clip_fraction        | 0.059        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.768       |
# |    explained_variance   | 0.733        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 44           |
# |    n_updates            | 360          |
# |    policy_gradient_loss | -0.0021      |
# |    value_loss           | 120          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 391          |
# |    ep_rew_mean          | 185          |
# | time/                   |              |
# |    fps                  | 920          |
# |    iterations           | 38           |
# |    time_elapsed         | 338          |
# |    total_timesteps      | 311296       |
# | train/                  |              |
# |    approx_kl            | 0.0052600345 |
# |    clip_fraction        | 0.0509       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.762       |
# |    explained_variance   | 0.778        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 72.4         |
# |    n_updates            | 370          |
# |    policy_gradient_loss | -0.00228     |
# |    value_loss           | 99.1         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 380          |
# |    ep_rew_mean          | 172          |
# | time/                   |              |
# |    fps                  | 923          |
# |    iterations           | 39           |
# |    time_elapsed         | 345          |
# |    total_timesteps      | 319488       |
# | train/                  |              |
# |    approx_kl            | 0.0050347284 |
# |    clip_fraction        | 0.0589       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.761       |
# |    explained_variance   | 0.849        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 52.8         |
# |    n_updates            | 380          |
# |    policy_gradient_loss | -0.00189     |
# |    value_loss           | 110          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 366         |
# |    ep_rew_mean          | 177         |
# | time/                   |             |
# |    fps                  | 925         |
# |    iterations           | 40          |
# |    time_elapsed         | 353         |
# |    total_timesteps      | 327680      |
# | train/                  |             |
# |    approx_kl            | 0.004654115 |
# |    clip_fraction        | 0.0449      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.745      |
# |    explained_variance   | 0.679       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 71.2        |
# |    n_updates            | 390         |
# |    policy_gradient_loss | -0.00466    |
# |    value_loss           | 183         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 357          |
# |    ep_rew_mean          | 175          |
# | time/                   |              |
# |    fps                  | 927          |
# |    iterations           | 41           |
# |    time_elapsed         | 361          |
# |    total_timesteps      | 335872       |
# | train/                  |              |
# |    approx_kl            | 0.0069501675 |
# |    clip_fraction        | 0.0847       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.78        |
# |    explained_variance   | 0.83         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 31.3         |
# |    n_updates            | 400          |
# |    policy_gradient_loss | -0.00203     |
# |    value_loss           | 63.3         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 350         |
# |    ep_rew_mean          | 182         |
# | time/                   |             |
# |    fps                  | 929         |
# |    iterations           | 42          |
# |    time_elapsed         | 369         |
# |    total_timesteps      | 344064      |
# | train/                  |             |
# |    approx_kl            | 0.005058091 |
# |    clip_fraction        | 0.05        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.72       |
# |    explained_variance   | 0.819       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 15.2        |
# |    n_updates            | 410         |
# |    policy_gradient_loss | -0.00188    |
# |    value_loss           | 96.2        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 361          |
# |    ep_rew_mean          | 185          |
# | time/                   |              |
# |    fps                  | 931          |
# |    iterations           | 43           |
# |    time_elapsed         | 378          |
# |    total_timesteps      | 352256       |
# | train/                  |              |
# |    approx_kl            | 0.0046044616 |
# |    clip_fraction        | 0.0448       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.737       |
# |    explained_variance   | 0.801        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 52.5         |
# |    n_updates            | 420          |
# |    policy_gradient_loss | -0.00181     |
# |    value_loss           | 118          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 367          |
# |    ep_rew_mean          | 201          |
# | time/                   |              |
# |    fps                  | 932          |
# |    iterations           | 44           |
# |    time_elapsed         | 386          |
# |    total_timesteps      | 360448       |
# | train/                  |              |
# |    approx_kl            | 0.0045125345 |
# |    clip_fraction        | 0.0417       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.713       |
# |    explained_variance   | 0.81         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 147          |
# |    n_updates            | 430          |
# |    policy_gradient_loss | -0.00211     |
# |    value_loss           | 139          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 373          |
# |    ep_rew_mean          | 206          |
# | time/                   |              |
# |    fps                  | 933          |
# |    iterations           | 45           |
# |    time_elapsed         | 394          |
# |    total_timesteps      | 368640       |
# | train/                  |              |
# |    approx_kl            | 0.0058933557 |
# |    clip_fraction        | 0.073        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.772       |
# |    explained_variance   | 0.848        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 25.4         |
# |    n_updates            | 440          |
# |    policy_gradient_loss | -0.00166     |
# |    value_loss           | 78.7         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 374          |
# |    ep_rew_mean          | 214          |
# | time/                   |              |
# |    fps                  | 933          |
# |    iterations           | 46           |
# |    time_elapsed         | 403          |
# |    total_timesteps      | 376832       |
# | train/                  |              |
# |    approx_kl            | 0.0045469436 |
# |    clip_fraction        | 0.0557       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.698       |
# |    explained_variance   | 0.869        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 20           |
# |    n_updates            | 450          |
# |    policy_gradient_loss | -0.00201     |
# |    value_loss           | 50.5         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 364         |
# |    ep_rew_mean          | 234         |
# | time/                   |             |
# |    fps                  | 935         |
# |    iterations           | 47          |
# |    time_elapsed         | 411         |
# |    total_timesteps      | 385024      |
# | train/                  |             |
# |    approx_kl            | 0.007529624 |
# |    clip_fraction        | 0.0753      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.712      |
# |    explained_variance   | 0.836       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 49.9        |
# |    n_updates            | 460         |
# |    policy_gradient_loss | -0.00234    |
# |    value_loss           | 37.8        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 356          |
# |    ep_rew_mean          | 236          |
# | time/                   |              |
# |    fps                  | 934          |
# |    iterations           | 48           |
# |    time_elapsed         | 420          |
# |    total_timesteps      | 393216       |
# | train/                  |              |
# |    approx_kl            | 0.0055543757 |
# |    clip_fraction        | 0.0621       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.738       |
# |    explained_variance   | 0.646        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 66.5         |
# |    n_updates            | 470          |
# |    policy_gradient_loss | -0.00186     |
# |    value_loss           | 77           |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 347          |
# |    ep_rew_mean          | 241          |
# | time/                   |              |
# |    fps                  | 936          |
# |    iterations           | 49           |
# |    time_elapsed         | 428          |
# |    total_timesteps      | 401408       |
# | train/                  |              |
# |    approx_kl            | 0.0036360892 |
# |    clip_fraction        | 0.0459       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.7         |
# |    explained_variance   | 0.818        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 10.6         |
# |    n_updates            | 480          |
# |    policy_gradient_loss | -0.0004      |
# |    value_loss           | 61           |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 342         |
# |    ep_rew_mean          | 236         |
# | time/                   |             |
# |    fps                  | 938         |
# |    iterations           | 50          |
# |    time_elapsed         | 436         |
# |    total_timesteps      | 409600      |
# | train/                  |             |
# |    approx_kl            | 0.005946204 |
# |    clip_fraction        | 0.0672      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.731      |
# |    explained_variance   | 0.916       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 16.2        |
# |    n_updates            | 490         |
# |    policy_gradient_loss | -0.00163    |
# |    value_loss           | 32.7        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 350         |
# |    ep_rew_mean          | 235         |
# | time/                   |             |
# |    fps                  | 940         |
# |    iterations           | 51          |
# |    time_elapsed         | 444         |
# |    total_timesteps      | 417792      |
# | train/                  |             |
# |    approx_kl            | 0.005076023 |
# |    clip_fraction        | 0.0593      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.729      |
# |    explained_variance   | 0.808       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 24.1        |
# |    n_updates            | 500         |
# |    policy_gradient_loss | -0.00167    |
# |    value_loss           | 58.2        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 347         |
# |    ep_rew_mean          | 230         |
# | time/                   |             |
# |    fps                  | 942         |
# |    iterations           | 52          |
# |    time_elapsed         | 452         |
# |    total_timesteps      | 425984      |
# | train/                  |             |
# |    approx_kl            | 0.004372049 |
# |    clip_fraction        | 0.0557      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.708      |
# |    explained_variance   | 0.93        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 17.8        |
# |    n_updates            | 510         |
# |    policy_gradient_loss | -0.00232    |
# |    value_loss           | 42.8        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 349          |
# |    ep_rew_mean          | 232          |
# | time/                   |              |
# |    fps                  | 943          |
# |    iterations           | 53           |
# |    time_elapsed         | 460          |
# |    total_timesteps      | 434176       |
# | train/                  |              |
# |    approx_kl            | 0.0034165361 |
# |    clip_fraction        | 0.0509       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.732       |
# |    explained_variance   | 0.877        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 10.8         |
# |    n_updates            | 520          |
# |    policy_gradient_loss | -0.00125     |
# |    value_loss           | 26.6         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 351          |
# |    ep_rew_mean          | 241          |
# | time/                   |              |
# |    fps                  | 943          |
# |    iterations           | 54           |
# |    time_elapsed         | 468          |
# |    total_timesteps      | 442368       |
# | train/                  |              |
# |    approx_kl            | 0.0050220834 |
# |    clip_fraction        | 0.0557       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.672       |
# |    explained_variance   | 0.952        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 11.4         |
# |    n_updates            | 530          |
# |    policy_gradient_loss | -0.00097     |
# |    value_loss           | 27           |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 342         |
# |    ep_rew_mean          | 243         |
# | time/                   |             |
# |    fps                  | 945         |
# |    iterations           | 55          |
# |    time_elapsed         | 476         |
# |    total_timesteps      | 450560      |
# | train/                  |             |
# |    approx_kl            | 0.004904538 |
# |    clip_fraction        | 0.0692      |
# ...
# | rollout/                |             |
# |    ep_len_mean          | 280         |
# |    ep_rew_mean          | 267         |
# | time/                   |             |
# |    fps                  | 992         |
# |    iterations           | 106         |
# |    time_elapsed         | 874         |
# |    total_timesteps      | 868352      |
# | train/                  |             |
# |    approx_kl            | 0.006317053 |
# |    clip_fraction        | 0.0472      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.607      |
# |    explained_variance   | 0.977       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.35        |
# |    n_updates            | 1050        |
# |    policy_gradient_loss | -0.000873   |
# |    value_loss           | 9.56        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 277          |
# |    ep_rew_mean          | 267          |
# | time/                   |              |
# |    fps                  | 993          |
# |    iterations           | 107          |
# |    time_elapsed         | 881          |
# |    total_timesteps      | 876544       |
# | train/                  |              |
# |    approx_kl            | 0.0038939263 |
# |    clip_fraction        | 0.0408       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.605       |
# |    explained_variance   | 0.922        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.15         |
# |    n_updates            | 1060         |
# |    policy_gradient_loss | -0.000193    |
# |    value_loss           | 10.5         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 306          |
# |    ep_rew_mean          | 263          |
# | time/                   |              |
# |    fps                  | 994          |
# |    iterations           | 108          |
# |    time_elapsed         | 889          |
# |    total_timesteps      | 884736       |
# | train/                  |              |
# |    approx_kl            | 0.0068427026 |
# |    clip_fraction        | 0.0614       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.598       |
# |    explained_variance   | 0.947        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.68         |
# |    n_updates            | 1070         |
# |    policy_gradient_loss | -0.00492     |
# |    value_loss           | 11.5         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 301          |
# |    ep_rew_mean          | 266          |
# | time/                   |              |
# |    fps                  | 994          |
# |    iterations           | 109          |
# |    time_elapsed         | 898          |
# |    total_timesteps      | 892928       |
# | train/                  |              |
# |    approx_kl            | 0.0049418295 |
# |    clip_fraction        | 0.0524       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.593       |
# |    explained_variance   | 0.924        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 23.2         |
# |    n_updates            | 1080         |
# |    policy_gradient_loss | -0.0016      |
# |    value_loss           | 38.6         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 297          |
# |    ep_rew_mean          | 267          |
# | time/                   |              |
# |    fps                  | 995          |
# |    iterations           | 110          |
# |    time_elapsed         | 904          |
# |    total_timesteps      | 901120       |
# | train/                  |              |
# |    approx_kl            | 0.0036468643 |
# |    clip_fraction        | 0.0421       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.597       |
# |    explained_variance   | 0.945        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.64         |
# |    n_updates            | 1090         |
# |    policy_gradient_loss | -0.00251     |
# |    value_loss           | 24.5         |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 277        |
# |    ep_rew_mean          | 268        |
# | time/                   |            |
# |    fps                  | 997        |
# |    iterations           | 111        |
# |    time_elapsed         | 911        |
# |    total_timesteps      | 909312     |
# | train/                  |            |
# |    approx_kl            | 0.00547349 |
# |    clip_fraction        | 0.0679     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.533     |
# |    explained_variance   | 0.821      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 8.83       |
# |    n_updates            | 1100       |
# |    policy_gradient_loss | -0.00204   |
# |    value_loss           | 20.8       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 266         |
# |    ep_rew_mean          | 270         |
# | time/                   |             |
# |    fps                  | 997         |
# |    iterations           | 112         |
# |    time_elapsed         | 919         |
# |    total_timesteps      | 917504      |
# | train/                  |             |
# |    approx_kl            | 0.005353842 |
# |    clip_fraction        | 0.0644      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.549      |
# |    explained_variance   | 0.859       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 8.25        |
# |    n_updates            | 1110        |
# |    policy_gradient_loss | -0.000658   |
# |    value_loss           | 14.1        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 264         |
# |    ep_rew_mean          | 269         |
# | time/                   |             |
# |    fps                  | 999         |
# |    iterations           | 113         |
# |    time_elapsed         | 926         |
# |    total_timesteps      | 925696      |
# | train/                  |             |
# |    approx_kl            | 0.004855008 |
# |    clip_fraction        | 0.0518      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.598      |
# |    explained_variance   | 0.895       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.63        |
# |    n_updates            | 1120        |
# |    policy_gradient_loss | -0.00148    |
# |    value_loss           | 9.65        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 278          |
# |    ep_rew_mean          | 268          |
# | time/                   |              |
# |    fps                  | 999          |
# |    iterations           | 114          |
# |    time_elapsed         | 933          |
# |    total_timesteps      | 933888       |
# | train/                  |              |
# |    approx_kl            | 0.0036643557 |
# |    clip_fraction        | 0.0435       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.516       |
# |    explained_variance   | 0.892        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 14.7         |
# |    n_updates            | 1130         |
# |    policy_gradient_loss | -0.000277    |
# |    value_loss           | 17.5         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 293          |
# |    ep_rew_mean          | 264          |
# | time/                   |              |
# |    fps                  | 1000         |
# |    iterations           | 115          |
# |    time_elapsed         | 941          |
# |    total_timesteps      | 942080       |
# | train/                  |              |
# |    approx_kl            | 0.0052495496 |
# |    clip_fraction        | 0.0554       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.605       |
# |    explained_variance   | 0.979        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.91         |
# |    n_updates            | 1140         |
# |    policy_gradient_loss | 0.000312     |
# |    value_loss           | 11.2         |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 291        |
# |    ep_rew_mean          | 263        |
# | time/                   |            |
# |    fps                  | 1001       |
# |    iterations           | 116        |
# |    time_elapsed         | 949        |
# |    total_timesteps      | 950272     |
# | train/                  |            |
# |    approx_kl            | 0.00554981 |
# |    clip_fraction        | 0.0538     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.62      |
# |    explained_variance   | 0.965      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 2.23       |
# |    n_updates            | 1150       |
# |    policy_gradient_loss | 0.000209   |
# |    value_loss           | 10.6       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 293         |
# |    ep_rew_mean          | 264         |
# | time/                   |             |
# |    fps                  | 1002        |
# |    iterations           | 117         |
# |    time_elapsed         | 956         |
# |    total_timesteps      | 958464      |
# | train/                  |             |
# |    approx_kl            | 0.006288412 |
# |    clip_fraction        | 0.059       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.567      |
# |    explained_variance   | 0.971       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 8.54        |
# |    n_updates            | 1160        |
# |    policy_gradient_loss | -0.00148    |
# |    value_loss           | 10.3        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 270         |
# |    ep_rew_mean          | 267         |
# | time/                   |             |
# |    fps                  | 1002        |
# |    iterations           | 118         |
# |    time_elapsed         | 963         |
# |    total_timesteps      | 966656      |
# | train/                  |             |
# |    approx_kl            | 0.002995444 |
# |    clip_fraction        | 0.0368      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.539      |
# |    explained_variance   | 0.917       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 7.75        |
# |    n_updates            | 1170        |
# |    policy_gradient_loss | -0.00121    |
# |    value_loss           | 23          |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 262         |
# |    ep_rew_mean          | 270         |
# | time/                   |             |
# |    fps                  | 1001        |
# |    iterations           | 119         |
# |    time_elapsed         | 973         |
# |    total_timesteps      | 974848      |
# | train/                  |             |
# |    approx_kl            | 0.006078828 |
# |    clip_fraction        | 0.0584      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.543      |
# |    explained_variance   | 0.959       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.67        |
# |    n_updates            | 1180        |
# |    policy_gradient_loss | -0.00139    |
# |    value_loss           | 16          |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 270          |
# |    ep_rew_mean          | 268          |
# | time/                   |              |
# |    fps                  | 1002         |
# |    iterations           | 120          |
# |    time_elapsed         | 981          |
# |    total_timesteps      | 983040       |
# | train/                  |              |
# |    approx_kl            | 0.0053938446 |
# |    clip_fraction        | 0.0612       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.554       |
# |    explained_variance   | 0.942        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 5.23         |
# |    n_updates            | 1190         |
# |    policy_gradient_loss | -0.00188     |
# |    value_loss           | 12.3         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 278         |
# |    ep_rew_mean          | 266         |
# | time/                   |             |
# |    fps                  | 1002        |
# |    iterations           | 121         |
# |    time_elapsed         | 988         |
# |    total_timesteps      | 991232      |
# | train/                  |             |
# |    approx_kl            | 0.005584779 |
# |    clip_fraction        | 0.0521      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.525      |
# |    explained_variance   | 0.951       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.87        |
# |    n_updates            | 1200        |
# |    policy_gradient_loss | -0.00138    |
# |    value_loss           | 17.6        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 288         |
# |    ep_rew_mean          | 266         |
# | time/                   |             |
# |    fps                  | 1002        |
# |    iterations           | 122         |
# |    time_elapsed         | 996         |
# |    total_timesteps      | 999424      |
# | train/                  |             |
# |    approx_kl            | 0.004029773 |
# |    clip_fraction        | 0.0555      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.571      |
# |    explained_variance   | 0.969       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 7.09        |
# |    n_updates            | 1210        |
# |    policy_gradient_loss | -0.0001     |
# |    value_loss           | 10.6        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 294          |
# |    ep_rew_mean          | 261          |
# | time/                   |              |
# |    fps                  | 1003         |
# |    iterations           | 123          |
# |    time_elapsed         | 1004         |
# |    total_timesteps      | 1007616      |
# | train/                  |              |
# |    approx_kl            | 0.0059879613 |
# |    clip_fraction        | 0.0655       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.577       |
# |    explained_variance   | 0.958        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.38         |
# |    n_updates            | 1220         |
# |    policy_gradient_loss | -0.00229     |
# |    value_loss           | 15.9         |
# ------------------------------------------

# %%
mean_reward, std_reward = evaluate_policy(model, env, n_eval_episodes=100)
print(f"mean_reward:{mean_reward:.2f} +/- {std_reward:.2f}")
# Out:
# mean_reward:271.88 +/- 19.14

# %%
model.save("lunarlander_ppo2")

# %%
import gymnasium as gym
from stable_baselines3 import PPO

# Eğitilmiş modeli yükle
model = PPO.load("lunarlander_ppo2.zip")

# Ortamı oluştur (görselleştirme açık)
env = gym.make("LunarLander-v3", render_mode="human")

episode_sayisi = 5  # 5 bölüm boyunca izle
for episode in range(episode_sayisi):
    obs, _ = env.reset()
    done = False
    total_reward = 0

    while not done:
        action, _ = model.predict(obs, deterministic=True)
        obs, reward, terminated, truncated, info = env.step(action)
        total_reward += reward
        done = terminated or truncated

    print(f"Bölüm {episode + 1}: Toplam Ödül = {total_reward}")

# Ortamı kapat
env.close()
# Out:
# Bölüm 1: Toplam Ödül = 289.9166707895297
# Bölüm 2: Toplam Ödül = 263.40235814206017
# Bölüm 3: Toplam Ödül = 263.35912748784745
# Bölüm 4: Toplam Ödül = 286.8455949962097
# Bölüm 5: Toplam Ödül = 265.56411569372347
